# %% [markdown]
# ## Ploting the neuronal connectivity from SCKAN dataset for circuit roles such as Motor and Sensory phenotypes

# %% [raw]
# # install relevant packages
# !pip install --quiet sckan-compare==0.0.6

# %%
#import the base class to access all features
from sckan_compare import SckanCompare

# access query sub-module; we can add all template queries in here and import as required
from sckan_compare import query

# %%
# species="Mus musculus"
species = "Rattus norvegicus"
# species="Homo sapiens"

# creating an instance of our class
sc = SckanCompare()
phenotypes = sc.get_valid_phenotypes_circuit_role()

# see what phenotypes are there
print("Available Phenotypes (with Circuit role): ", phenotypes.values())

# to execute a SPARQL query
result = sc.execute_query(query.neuron_circuit_role_query, species)
result_df = sc.get_filtered_dataframe(result, species=species, filter_column="Phenotype", filter_value="Sensory phenotype")

# just to show output obtained
print(result_df.shape)
# Out:
# Available Phenotypes (with Circuit role):  dict_values(['Intrinsic phenotype', 'Motor phenotype', 'Sensory phenotype'])
# (135, 12)

# %% [markdown]
# ## Ploting neuronal connectivity for  on basic anatomy map

# %%
fig = sc.plot_dataframe_anatomy_vis(result_df, species=species)
fig
# Out:
# FigureWidget({
#     'data': [{'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '1c722455-69c0-466b-a572-96785f151d82',
#               'x': [24, 25, 25, 24, 24],
#               'y': [2, 2, 3, 3, 2]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'd76c1532-49d0-40e2-a6e7-ebbd8c8d48da',
#               'x': [26, 27, 27, 26, 26],
#               'y': [2, 2, 3, 3, 2]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'dcb18cb2-ffff-4008-9877-4d1f8180a497',
#               'x': [1, 5, 5, 1, 1],
#               'y': [3, 3, 7, 7, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '4b60366e-38d8-4542-870c-1930f879f6b4',
#               'x': [5, 6, 6, 5, 5],
#               'y': [3, 3, 7, 7, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '84ba9633-0ab5-4118-be54-99a2a57341e1',
#               'x': [6, 8, 8, 6, 6],
#               'y': [5, 5, 6, 6, 5]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'afa01d69-1a97-4bef-a587-4eab7fe792e6',
#               'x': [7, 9, 9, 7, 7],
#               'y': [4, 4, 5, 5, 4]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '5e6fb0e3-622b-4c62-812d-25206cbff69a',
#               'x': [8, 10, 10, 8, 8],
#               'y': [5, 5, 6, 6, 5]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '5c473208-e4a2-4342-8d8a-a833a505bda9',
#               'x': [10, 18, 18, 10, 10],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'ce15f61a-16c1-4f64-a4a6-719c6c063e29',
#               'x': [18, 31, 31, 18, 18],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '8981e39f-f56d-4c78-9dba-04f1a2817122',
#               'x': [31, 37, 37, 31, 31],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '4174bbde-8a0e-49cc-90dd-977349a4e6a5',
#               'x': [37, 41, 41, 37, 37],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '1ae8190c-6854-4a57-9dc8-38ac1fdd4e54',
#               'x': [41, 42, 42, 41, 41],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'ebb3dafe-1624-4926-a0ce-7829d728ac74',
#               'x': [10, 41, 41, 10, 10],
#               'y': [5, 5, 6, 6, 5]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '05dc2cc3-ff0f-43d7-b728-7efdf299051e',
#               'x': [10, 11, 11, 10, 10],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '90739a60-2ac8-4874-9321-0a73ac5fb00e',
#               'x': [13, 14, 14, 13, 13],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '22d5afc0-ddb8-4f41-83ad-d8a83c8b8feb',
#               'x': [17, 18, 18, 17, 17],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'fb19ec06-7c65-4c4d-8498-5ac0b0c1bb72',
#               'x': [18, 41, 41, 18, 18],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '7d69ff38-5f87-435a-9294-950f6b57a6f1',
#               'x': [10, 13, 13, 10, 10],
#               'y': [7, 7, 8, 8, 7]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '1ac8c6f1-ca3d-4b0e-8f26-2c0b24ff169d',
#               'x': [35, 38, 38, 35, 35],
#               'y': [7, 7, 8, 8, 7]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'f7d2d2ee-7c60-4e61-9d26-3ad71094af4e',
#               'x': [6, 8, 8, 6, 6],
#               'y': [8, 8, 9, 9, 8]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'e146a54f-6e06-4b80-8a68-7544278a41a3',
#               'x': [15, 17, 17, 15, 15],
#               'y': [8, 8, 9, 9, 8]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '15e98646-4ae8-43c5-8fb9-ad5f29fe8bc6',
#               'x': [19, 20, 20, 19, 19],
#               'y': [8, 8, 9, 9, 8]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '5cac4fdc-9bec-460d-9db2-1296ec97c846',
#               'x': [6, 8, 8, 7, 7, 6, 6],
#               'y': [9, 9, 11, 11, 10, 10, 9]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '21f72913-632f-47b9-9b1f-21d82404d684',
#               'x': [18, 21, 21, 18, 18],
#               'y': [9, 9, 11, 11, 9]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '6ed2bd24-5a10-4604-a716-83a46bb3746b',
#               'x': [21, 23, 23, 21, 21],
#               'y': [9, 9, 10, 10, 9]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '0bff076a-0a90-4893-ab78-e5fbbae259ff',
#               'x': [29, 30, 30, 29, 29],
#               'y': [13, 13, 14, 14, 13]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '664b5ded-6b5d-44c7-b66d-4ed73aa73217',
#               'x': [40, 41, 41, 40, 40],
#               'y': [10, 10, 11, 11, 10]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '3bb63785-ced8-4b02-811c-1919ad427808',
#               'x': [18, 28, 28, 18, 18],
#               'y': [11, 11, 13, 13, 11]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '824bfd68-185a-430e-b8fe-5e64eec9bdd4',
#               'x': [29, 41, 41, 29, 29],
#               'y': [11, 11, 13, 13, 11]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '23b65794-032c-45d1-b2d6-0ce96a93d6be',
#               'x': [22, 23, 23, 22, 22],
#               'y': [13, 13, 14, 14, 13]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'ff9de682-6aaa-42fa-b87d-92f90fb9486a',
#               'x': [24, 25, 25, 24, 24],
#               'y': [13, 13, 14, 14, 13]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '91241c6d-f8b8-4d74-b932-16d36d4682be',
#               'x': [18, 41, 41, 18, 18],
#               'y': [14, 14, 16, 16, 14]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '8d26d0e9-04c1-4550-a3bf-1e9f30eb75ab',
#               'x': [37, 38, 38, 37, 37],
#               'y': [16, 16, 17, 17, 16]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '8788aca1-2cdf-4cdb-84bd-6908c2afc140',
#               'x': [40, 41, 41, 40, 40],
#               'y': [16, 16, 17, 17, 16]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '30a9b180-5785-436c-b92d-066cb782ed99',
#               'x': [35, 41, 41, 35, 35],
#               'y': [17, 17, 19, 19, 17]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'inferior vagus X ganglion',
#               'text': 'inferior vagus X ganglion',
#               'type': 'scatter',
#               'uid': '4560a9c8-daa6-4ccb-96f1-fcbf643a2a10',
#               'x': [6.5],
#               'y': [8.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'nucleus of solitary tract',
#               'text': 'nucleus of solitary tract',
#               'type': 'scatter',
#               'uid': '7f93885c-c398-447e-92b7-8e175071dbc8',
#               'x': [5.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'vagus nerve',
#               'text': 'vagus nerve',
#               'type': 'scatter',
#               'uid': 'eabcab3f-0834-43c8-8372-4f11c0e9ff70',
#               'x': [16.5],
#               'y': [8.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('inferior vagus X ganglion to o' ... 'us X ganglion to NTS via vagus'),
#               'showlegend': False,
#               'text': ('inferior vagus X ganglion to o' ... 'us X ganglion to NTS via vagus'),
#               'type': 'scatter',
#               'uid': '3c8efdc5-61f8-49eb-acbb-0e6d165d7ea3',
#               'x': [6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5],
#               'y': [8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('inferior vagus X ganglion to o' ... 'us X ganglion to NTS via vagus'),
#               'showlegend': False,
#               'text': ('inferior vagus X ganglion to o' ... 'us X ganglion to NTS via vagus'),
#               'type': 'scatter',
#               'uid': '12f69d70-df09-4353-9635-8f5a2db147f0',
#               'x': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5],
#               'y': [8.5, 8.2, 7.9, 7.6, 7.3, 7.0, 6.699999999999999, 6.4, 6.1,
#                     5.8, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'inferior vagus X ganglion',
#               'text': 'inferior vagus X ganglion',
#               'type': 'scatter',
#               'uid': 'b7b9c4fe-1e1b-4290-bd25-918c24c6c384',
#               'x': [6.5],
#               'y': [8.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'thymus',
#               'text': 'thymus',
#               'type': 'scatter',
#               'uid': '4c321e10-120a-403c-ace8-16f6804eddc5',
#               'x': [20.5],
#               'y': [9.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'vagus nerve',
#               'text': 'vagus nerve',
#               'type': 'scatter',
#               'uid': '4691dd08-4cb9-490c-b887-7938b40f00dc',
#               'x': [16.5],
#               'y': [8.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'Inferior vagus X ganglion to thymus gland via vagus nerve',
#               'showlegend': False,
#               'text': 'Inferior vagus X ganglion to thymus gland via vagus nerve',
#               'type': 'scatter',
#               'uid': '9e95d601-61fe-4be4-b26e-0d1fcf129da6',
#               'x': [6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5],
#               'y': [8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5, 8.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'Inferior vagus X ganglion to thymus gland via vagus nerve',
#               'showlegend': False,
#               'text': 'Inferior vagus X ganglion to thymus gland via vagus nerve',
#               'type': 'scatter',
#               'uid': 'bb731dc9-54f2-46a8-8dde-82e001d88ebd',
#               'x': [16.5, 16.9, 17.3, 17.7, 18.1, 18.5, 18.9, 19.3, 19.7, 20.1,
#                     20.5],
#               'y': [8.5, 8.6, 8.7, 8.8, 8.9, 9.0, 9.1, 9.2, 9.3, 9.4, 9.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '62b42a3d-a61b-4fa9-a9af-a59d4df69e8a',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'S1 segment',
#               'text': 'S1 segment',
#               'type': 'scatter',
#               'uid': 'bfe65e9a-89c3-46b1-9553-4205b6e951de',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pudendal nerve',
#               'text': 'pudendal nerve',
#               'type': 'scatter',
#               'uid': '09a4c5f6-1a54-4dc7-9748-f0e3d54dcc13',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 12',
#               'showlegend': False,
#               'text': 'neuron type kblad 12',
#               'type': 'scatter',
#               'uid': '24cd7aff-9a63-46db-ac99-1fe9ebe0cba3',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 12',
#               'showlegend': False,
#               'text': 'neuron type kblad 12',
#               'type': 'scatter',
#               'uid': 'e3c5e213-fbda-4fd9-9270-80bf45ba97b5',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sixth lumbar dorsal root ganglion',
#               'text': 'sixth lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '1f0fc377-5483-45f5-8370-55659473ecdb',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'S1 segment',
#               'text': 'S1 segment',
#               'type': 'scatter',
#               'uid': 'b0d086e7-1cbe-4e8a-8f6b-040b9d90bdea',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pudendal nerve',
#               'text': 'pudendal nerve',
#               'type': 'scatter',
#               'uid': '7379e525-c392-45f0-be4c-b291b2663b59',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 12',
#               'showlegend': False,
#               'text': 'neuron type kblad 12',
#               'type': 'scatter',
#               'uid': '1e90b6f5-059c-4da9-8596-81b9c2d251d6',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 12',
#               'showlegend': False,
#               'text': 'neuron type kblad 12',
#               'type': 'scatter',
#               'uid': '16a7590a-89ff-44ba-9b93-41098b9e2e87',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'second lumbar dorsal root ganglion',
#               'text': 'second lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '422443ec-a437-4b37-9c8a-ef5ac387f029',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'L1 segment of lumbar spinal cord',
#               'text': 'L1 segment of lumbar spinal cord',
#               'type': 'scatter',
#               'uid': '94a83dd2-317b-43d9-92ff-85fdd7437c5e',
#               'x': [31.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': '6223a052-e044-4c9a-9c94-ff47d9221155',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': 'a9af0694-1d5e-4352-8ba7-21cf8fce277e',
#               'x': [32.5, 33.3, 34.1, 34.9, 35.7, 36.5, 37.3, 38.1, 38.9, 39.7,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': 'f21ad4e4-b5fe-4eb6-ae68-686556baf7a6',
#               'x': [40.5, 39.6, 38.7, 37.8, 36.9, 36.0, 35.1, 34.2, 33.3, 32.4,
#                     31.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first lumbar dorsal root ganglion',
#               'text': 'first lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'a6a77aa2-2a4f-45cb-a9ce-e2c7f14c1f9c',
#               'x': [31.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'L1 segment of lumbar spinal cord',
#               'text': 'L1 segment of lumbar spinal cord',
#               'type': 'scatter',
#               'uid': 'e9ea76b4-6e42-4ffd-8936-1b73f4d0e4a9',
#               'x': [31.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': '9729d44f-f3ce-48e7-be6b-0a1b3cc90cee',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': 'a711d25c-aaaf-430c-adee-4a18a72b63f8',
#               'x': [31.5, 32.4, 33.3, 34.2, 35.1, 36.0, 36.9, 37.8, 38.7, 39.6,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '05b5458c-61d0-4bd6-88fc-cd18435849b5',
#               'x': [40.5, 39.6, 38.7, 37.8, 36.9, 36.0, 35.1, 34.2, 33.3, 32.4,
#                     31.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'second lumbar dorsal root ganglion',
#               'text': 'second lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '9b33c961-5a42-451c-8336-0ee37f5c9195',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'L2 segment of lumbar spinal cord',
#               'text': 'L2 segment of lumbar spinal cord',
#               'type': 'scatter',
#               'uid': '7bc11f39-adc5-47c8-bee0-46c1b3b41a93',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'dcbc198b-cd1d-49b0-9399-3fe2792ec98a',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '130344cc-b6b3-4f2e-b05a-ad0fb861512a',
#               'x': [32.5, 33.3, 34.1, 34.9, 35.7, 36.5, 37.3, 38.1, 38.9, 39.7,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': 'b8881192-db66-405d-a6a1-b9285c515e2f',
#               'x': [40.5, 39.7, 38.9, 38.1, 37.3, 36.5, 35.7, 34.9, 34.1, 33.3,
#                     32.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first lumbar dorsal root ganglion',
#               'text': 'first lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '83b18627-355e-4467-930f-09101bdafa67',
#               'x': [31.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'L2 segment of lumbar spinal cord',
#               'text': 'L2 segment of lumbar spinal cord',
#               'type': 'scatter',
#               'uid': '0803936f-251d-41ec-b8d7-7265e4baceff',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': '203173d5-364e-4348-8e54-9d34d07e6722',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': 'b13c1411-3975-404b-a67e-8ae84fbe4262',
#               'x': [31.5, 32.4, 33.3, 34.2, 35.1, 36.0, 36.9, 37.8, 38.7, 39.6,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '83576a91-682b-42f9-b3e9-9bb9b1f7daa3',
#               'x': [40.5, 39.7, 38.9, 38.1, 37.3, 36.5, 35.7, 34.9, 34.1, 33.3,
#                     32.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '5056b4eb-867a-47cf-a9a3-abd1942ea39f',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'S1 segment',
#               'text': 'S1 segment',
#               'type': 'scatter',
#               'uid': '8b3b7f15-0eec-4653-a290-4cc1f8e9395a',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': '5f77afbd-b146-4759-b51a-51ea96b43416',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '73af4ab9-f36b-40fe-8c7f-b3ec55d39d85',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '88ab5e74-08d7-482b-ba50-6b22cd096cc5',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sixth lumbar dorsal root ganglion',
#               'text': 'sixth lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'faad0bc8-12ab-4a22-be19-397c99e360d3',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'S1 segment',
#               'text': 'S1 segment',
#               'type': 'scatter',
#               'uid': '402b4562-50c1-4ae8-b547-01d9e1a7b74b',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'b92f652e-8d8c-4e6c-85c1-d909f2e7e5ba',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '447b411e-9ca8-472b-af08-aef19fb128a1',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '8eab3a59-c231-4820-b18a-11e0ce63f83f',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'a80806c5-7669-434d-9786-826cedc8a461',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'S1 segment',
#               'text': 'S1 segment',
#               'type': 'scatter',
#               'uid': 'f4aa73d1-1f41-46b2-9beb-1c441629ba1a',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': 'f069a668-dad3-426f-98e9-1eda8d3345b1',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'bd67a812-2685-4b05-92ee-85fc1af581f6',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '82c9f21a-e04a-4780-a1b9-a4c393cd22d4',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sixth lumbar dorsal root ganglion',
#               'text': 'sixth lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'ee03d176-3796-4602-97ff-b6cc1f0d3a9b',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'S1 segment',
#               'text': 'S1 segment',
#               'type': 'scatter',
#               'uid': '99be0dd2-09ac-4d6a-8388-e03f3c2e422a',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': 'c2048f28-89c7-4b04-b7ca-facd411a4730',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'e7df89fd-a7ab-4747-a3e3-b69e7260ff04',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'b2dccd87-759e-4eca-910c-903c1af5a7c6',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 15.4, 14.3, 13.2, 12.1, 11.0, 9.899999999999999,
#                     8.799999999999999, 7.699999999999999, 6.6, 5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'second lumbar dorsal root ganglion',
#               'text': 'second lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'bcc5512e-4305-457c-9280-6e47afe30d91',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'L1 segment of lumbar spinal cord',
#               'text': 'L1 segment of lumbar spinal cord',
#               'type': 'scatter',
#               'uid': 'd414f840-5d8a-42fd-809a-b4b80c6c468f',
#               'x': [31.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'white matter of spinal cord',
#               'text': 'white matter of spinal cord',
#               'type': 'scatter',
#               'uid': 'fb23adb4-84ab-4a33-b923-992d4d4286cd',
#               'x': [26.5],
#               'y': [2.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '69ed56a8-11f7-4d92-a570-677c413c8d2f',
#               'x': [32.5, 31.9, 31.3, 30.7, 30.1, 29.5, 28.9, 28.3, 27.7, 27.1,
#                     26.5],
#               'y': [5.5, 5.2, 4.9, 4.6, 4.3, 4.0, 3.6999999999999997, 3.4,
#                     3.0999999999999996, 2.8, 2.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
# ...
#               'type': 'scatter',
#               'uid': 'a9239f59-6db1-4bcb-a541-53e072dc79b6',
#               'x': [32.5, 33.3, 34.1, 34.9, 35.7, 36.5, 37.3, 38.1, 38.9, 39.7,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '4c4f7a90-a0ed-4d3a-8fe3-252673c77967',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'aff7abc2-1835-4cf9-9e72-f4b1c1c54904',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Dome of the Bladder',
#               'text': 'Dome of the Bladder',
#               'type': 'scatter',
#               'uid': '1ce6b29d-4d52-4685-abf3-e81f1e2a4807',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '3d19f69a-d4f6-419f-a14a-a4bd451d7eaa',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'd7e77c70-1b00-44dd-b179-5933b2d3a2ce',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '7092bc2f-fdef-43c5-83b3-3a8abc16dc5a',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sixth lumbar dorsal root ganglion',
#               'text': 'sixth lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'cde57706-b46a-489f-a292-d0d6081bca96',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Dome of the Bladder',
#               'text': 'Dome of the Bladder',
#               'type': 'scatter',
#               'uid': '8a233518-0e55-46dc-9378-527113b4eb62',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': 'e8228152-0e03-489d-aa91-3257c7ae63c4',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'f9622243-07b0-49a7-9440-23fc8ed98122',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '82bbcd24-3df7-4692-b41c-727ce36d3049',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'second lumbar dorsal root ganglion',
#               'text': 'second lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '1ff54441-3037-4648-aad9-eafcc370e6ce',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder neck',
#               'text': 'Arteriole in connective tissue of bladder neck',
#               'type': 'scatter',
#               'uid': '9571516b-c130-4173-88aa-c22f577a9959',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '665909da-8889-4193-ad03-645b14fa7295',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': 'bf640698-e949-4d58-90e5-5efb1c286397',
#               'x': [32.5, 33.3, 34.1, 34.9, 35.7, 36.5, 37.3, 38.1, 38.9, 39.7,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '0cc89147-e798-45b5-bc37-a8915a810402',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sixth lumbar dorsal root ganglion',
#               'text': 'sixth lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '195a12a3-6f4e-4ed4-b02b-02cb8cf54a19',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder neck',
#               'text': 'Arteriole in connective tissue of bladder neck',
#               'type': 'scatter',
#               'uid': '4f1b4b2e-7ebd-447c-87da-149a6c4c0056',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '4f9394cf-1340-4e2a-b4d0-e20f1fd8b118',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '70d6f33c-73e8-4aa9-b549-9047a024c633',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '0d9f636b-236a-4ac1-88e7-8305bf9fbd5d',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'second lumbar dorsal root ganglion',
#               'text': 'second lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '5a784761-eddd-40bc-92a3-56a80071a68e',
#               'x': [32.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': 'c236ef9b-a92a-4630-aa13-83933329ffbc',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '397db854-6f30-4f50-b1f4-82c935e00771',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '901439a3-47d3-4d5c-8dff-e90ea5a2c0ca',
#               'x': [32.5, 33.3, 34.1, 34.9, 35.7, 36.5, 37.3, 38.1, 38.9, 39.7,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 11',
#               'showlegend': False,
#               'text': 'neuron type kblad 11',
#               'type': 'scatter',
#               'uid': '2d54eff8-79f9-4ee2-b14f-30926dcfc4c8',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'sixth lumbar dorsal root ganglion',
#               'text': 'sixth lumbar dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'b054ed94-480b-4dc2-93e1-727d78103bd9',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': '6bc4aa96-575f-4682-b4a8-74fd8ffc285c',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '5ecd0ad1-9f99-442a-bf2a-3a49cd2c2ccf',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c52166e6-c5c8-42e5-844e-dc3ea6da459c',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '16084d45-cf1d-4985-bf65-0115fb3a3c1c',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]}],
#     'layout': {'height': 500,
#                'hoverdistance': -1,
#                'hovermode': 'closest',
#                'showlegend': False,
#                'template': '...',
#                'xaxis': {'range': [0, 43],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False},
#                'yaxis': {'range': [21, 0],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False}}
# })

# %% [markdown]
# ## Plot the neuronal connectivity as a simple map

# %%
selected_Region_A = "first sacral dorsal root ganglion"
selected_Region_B = "neck of urinary bladder"

fig = sc.plot_dataframe_block_vis(result_df, selected_Region_A, selected_Region_B)
fig
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'da7a68ab-a44d-4b19-acaa-d546047b42a6',
#               'x': [300.0],
#               'y': [125]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'neck of urinary bladder',
#               'text': 'neck of urinary bladder',
#               'type': 'scatter',
#               'uid': '52d7d24c-bf41-4840-a52c-6ea99aff084e',
#               'x': [300.0],
#               'y': [775]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': '3471a778-f95b-448d-862c-f52648824724',
#               'x': [64],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '285fb2fc-4223-4ae7-a1d1-181ea4fc4ea9',
#               'x': [300.0, 276.4, 252.8, 229.2, 205.6, 182.0, 158.39999999999998,
#                     134.79999999999998, 111.19999999999999, 87.6, 64.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'f855956e-4322-40f2-941c-3bf6a01b7c0f',
#               'x': [64.0, 87.6, 111.2, 134.8, 158.4, 182.0, 205.60000000000002,
#                     229.20000000000002, 252.8, 276.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': 'f40517a6-bc1c-419c-bbb0-7a2e6a6c87c6',
#               'x': [214],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '9da7a047-cdd8-4fe7-b24c-25968fe82e80',
#               'x': [300.0, 291.4, 282.8, 274.2, 265.6, 257.0, 248.39999999999998,
#                     239.8, 231.2, 222.6, 214.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '645243e7-3d95-4a13-be7a-19eda70bce2f',
#               'x': [214.0, 222.6, 231.2, 239.8, 248.4, 257.0, 265.6, 274.2, 282.8,
#                     291.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'white matter of spinal cord',
#               'text': 'white matter of spinal cord',
#               'type': 'scatter',
#               'uid': '835788cc-67b0-4587-bd6e-e7d9cab4697b',
#               'x': [364],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '1d77a1b7-b832-43a1-a981-21909905e184',
#               'x': [300.0, 306.4, 312.8, 319.2, 325.6, 332.0, 338.4, 344.8, 351.2,
#                     357.6, 364.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '4efe9fd7-b95d-495f-b855-cf04d837b896',
#               'x': [364.0, 357.6, 351.2, 344.8, 338.4, 332.0, 325.6, 319.2, 312.8,
#                     306.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '0b66562a-7324-4b3f-8add-5247f8f19a66',
#               'x': [514],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c075eac3-f697-4c99-a94b-030de2ba1bbd',
#               'x': [300.0, 321.4, 342.8, 364.2, 385.6, 407.0, 428.4, 449.8,
#                     471.20000000000005, 492.6, 514.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '11491883-29ca-4323-9620-ff83be702a92',
#               'x': [514.0, 492.6, 471.2, 449.8, 428.4, 407.0, 385.6, 364.2,
#                     342.79999999999995, 321.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]}],
#     'layout': {'annotations': [{'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 20},
#                                 'showarrow': False,
#                                 'text': 'first sacral dorsal root ganglion',
#                                 'x': 297.0,
#                                 'xref': 'x',
#                                 'y': 0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 20},
#                                 'showarrow': False,
#                                 'text': 'neck of urinary bladder',
#                                 'x': 300.0,
#                                 'xref': 'x',
#                                 'y': 900,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'pelvic ganglion',
#                                 'x': 64,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'pelvic splanchnic nerve',
#                                 'x': 214,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'white matter of spinal cord',
#                                 'x': 364,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'bladder nerve',
#                                 'x': 514,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'}],
#                'height': 500,
#                'hoverdistance': -1,
#                'hovermode': 'closest',
#                'images': [{'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... '8Bn1KJrMY+eqcAAAAASUVORK5CYII='),
#                            'x': 300.0,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 125,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'H//r1zfwYXUiQAAAAASUVORK5CYII='),
#                            'x': 297.0,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 775,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 64,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 214,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 364,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 514,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'}],
#                'shapes': [{'fillcolor': 'PaleTurquoise',
#                            'line': {'color': 'PaleTurquoise'},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 200.0,
#                            'x1': 400.0,
#                            'xref': 'x',
#                            'y0': 50,
#                            'y1': 200,
#                            'yref': 'y'},
#                           {'fillcolor': 'LightGreen',
#                            'line': {'color': 'LightGreen'},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 200.0,
#                            'x1': 400.0,
#                            'xref': 'x',
#                            'y0': 700,
#                            'y1': 850,
#                            'yref': 'y'}],
#                'showlegend': False,
#                'template': '...',
#                'xaxis': {'range': [0, 600],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False},
#                'yaxis': {'range': [900, 0],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False}}
# })
