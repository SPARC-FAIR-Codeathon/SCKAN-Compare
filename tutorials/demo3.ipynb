# %% [markdown]
# ## Ploting the neuronal connectivity from SCKAN dataset for circuit roles such as Motor and Sensory phenotypes

# %%
# install relevant packages

# !pip install sckan-compare==0.0.6
# !pip install dash
# !pip install dash-cytoscape
# Out:
# Requirement already satisfied: sckan-compare==0.0.6 in /usr/local/lib/python3.10/dist-packages (0.0.6)
# Requirement already satisfied: dash in /usr/local/lib/python3.10/dist-packages (2.11.1)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<2.3.0 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (5.13.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.27.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dash) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from dash) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.5.6)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash) (8.1.6)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<2.3.0->dash) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.4)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: dash-cytoscape in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: dash in /usr/local/lib/python3.10/dist-packages (from dash-cytoscape) (2.11.1)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (2.2.5)
# Requirement already satisfied: Werkzeug<2.3.0 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (5.13.1)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (4.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (2.27.1)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (1.3.4)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (1.8.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash->dash-cytoscape) (1.5.6)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash->dash-cytoscape) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash->dash-cytoscape) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash->dash-cytoscape) (8.1.6)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash->dash-cytoscape) (8.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<2.3.0->dash->dash-cytoscape) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash->dash-cytoscape) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash->dash-cytoscape) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->dash->dash-cytoscape) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash->dash-cytoscape) (3.4)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash->dash-cytoscape) (1.16.0)

# %% [markdown]
# ## Ploting neuronal connectivity for  on basic anatomy map

# %%
#import the base class to access all features
from sckan_compare import SckanCompare

# access query sub-module; we can add all template queries in here and import as required
from sckan_compare import query

# access phenotypes and species
from sckan_compare import utils
# Out:
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:290: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
species = "Rattus norvegicus"
# species="Homo sapiens"

# creating an instance of our class
sc = SckanCompare(species=species)
ph = utils.get_circuit_roles()

# see what phenotypes are there
print(ph)

# to execute a SPARQL query
result = sc.execute_query(query.neuron_circuit_role_query)
result_df = sc.get_neuron_dataframe(result, species_name=species, phenotype_name = 'Sensory phenotype' )

# just to show output obtained
print(len(result))
print(len(result_df))
# Out:
# (['Homo sapiens', 'Mammal', 'Rattus norvegicus'], ['Motor phenotype', 'Sensory phenotype'])
# 29971
# 135
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.loc[:, "Region_A"] = filtered_df.A.map(replacement_dict)
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.loc[:, "Region_B"] = filtered_df.B.map(replacement_dict)
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.loc[:, "Region_C"] = filtered_df.C.map(replacement_dict)

# %%
# visualize a specific connection

# sc.add_connection(species="species", region_A="postganglionic sympathetic fiber", region_B="corpus cavernosum penis", region_C="urethral sphincter", neuron="set_neuron_name")
sc.reset_vis()
for i in range(len(result_df)):
    sc.add_connection(region_A=result_df.iloc[i,7],
                      region_B=result_df.iloc[i,8],
                      region_C=result_df.iloc[i,9],
                      neuron=result_df.iloc[i,1])

fig = sc.get_graph()
fig
# fig.show('colab')

# to clear graph
# sc.reset_vis()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="171f187e-0923-42c7-83c9-394e0f18b5c0" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("171f187e-0923-42c7-83c9-394e0f18b5c0")) {                    Plotly.newPlot(                        "171f187e-0923-42c7-83c9-394e0f18b5c0",                        [{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[24,25,25,24,24],"y":[2,2,3,3,2],"type":"scatter","uid":"ec937b22-4c48-47d3-bec2-ccb88244342a"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[26,27,27,26,26],"y":[2,2,3,3,2],"type":"scatter","uid":"e2103311-f100-411e-a901-99d29a47c46c"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[1,5,5,1,1],"y":[3,3,7,7,3],"type":"scatter","uid":"2c2925d5-7662-428a-b8e7-fb2eaa063121"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[5,6,6,5,5],"y":[3,3,7,7,3],"type":"scatter","uid":"16e6e7e4-72df-4e2a-b128-284fc88c177b"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[6,8,8,6,6],"y":[5,5,6,6,5],"type":"scatter","uid":"ed42f18d-ac88-44b0-a5a9-e1c7d1688d86"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[7,9,9,7,7],"y":[4,4,5,5,4],"type":"scatter","uid":"19157117-9eb9-4d22-ae32-959cd59c6517"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[8,10,10,8,8],"y":[5,5,6,6,5],"type":"scatter","uid":"44a445f5-daf1-4cb4-bfb2-1d1114f1d19d"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[10,18,18,10,10],"y":[3,3,5,5,3],"type":"scatter","uid":"803ff6bb-fd08-4f2c-bfe3-49a234d28058"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[18,31,31,18,18],"y":[3,3,5,5,3],"type":"scatter","uid":"2b46f499-01af-455e-82be-3f1f622337b5"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[31,37,37,31,31],"y":[3,3,5,5,3],"type":"scatter","uid":"b8ca3e94-5a98-420f-a46b-0b3579d6c785"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[37,41,41,37,37],"y":[3,3,5,5,3],"type":"scatter","uid":"468a268f-4490-4515-8327-eff8b0954a34"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[41,42,42,41,41],"y":[3,3,5,5,3],"type":"scatter","uid":"11cb76f3-ebff-4aed-9bf3-8681f05c9889"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":false,"text":"<set name>","x":[10,41,41,10,10],"y":[5,5,6,6,5],"type":"scatter","uid":"bc05f23b-5c69-43a4-85e0-6a0086379a9c"},{"fill":"toself","fillcolor":"#C5CAE9","hoverinfo":"text","hoveron":"fills","line":{"color":"#4051BF"},"mode":"lines","showlegend":fal ...

# %% [markdown]
# ## Plot the neuronal connectivity as a simple map

# %%
# species="Mus musculus"
species = "Rattus norvegicus"
# species="Homo sapiens"

# creating an instance of our class
sc = SckanCompare(species=species)

# to execute a SPARQL query
# to execute a SPARQL query
result = sc.execute_query(query.neuron_circuit_role_query)
result_df = sc.get_neuron_dataframe(result, species_name=species, phenotype_name = 'Sensory phenotype' )

# just to show output obtained
print(len(result))
print(len(result_df))
# Out:
# 29971
# 135
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:170: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:171: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.10/dist-packages/sckan_compare/__init__.py:172: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sckan_compare.simplevis import SimpleVisualizer

selected_Region_A = "first sacral dorsal root ganglion"
selected_Region_B = "neck of urinary bladder"
simvis = SimpleVisualizer()
fig = simvis.plot_figure(result_df, selected_Region_A, selected_Region_B)
fig
# fig.show('colab')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4dbb94fb-96d6-4d30-8223-34c95ffc3258" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dbb94fb-96d6-4d30-8223-34c95ffc3258")) {                    Plotly.newPlot(                        "4dbb94fb-96d6-4d30-8223-34c95ffc3258",                        [{"hoverinfo":"text","marker":{"symbol":"circle"},"mode":"markers","name":"first sacral dorsal root ganglion","text":"first sacral dorsal root ganglion","x":[300.0],"y":[125],"type":"scatter","uid":"3c237a88-f0e5-4197-810c-725a6ec65963"},{"hoverinfo":"text","marker":{"symbol":"circle"},"mode":"markers","name":"neck of urinary bladder","text":"neck of urinary bladder","x":[300.0],"y":[775],"type":"scatter","uid":"80d39c7e-96aa-44f9-89bf-a0f97e674d64"},{"hoverinfo":"text","marker":{"symbol":"circle"},"mode":"markers","name":"first sacral dorsal root ganglion","text":"first sacral dorsal root ganglion","x":[64],"y":[450.0],"type":"scatter","uid":"35f3e21d-5df5-4981-a377-fed2c8764c43"},{"hoverinfo":"text","line":{"color":"#FF0000"},"mode":"lines","name":"neuron type kblad 10","showlegend":false,"text":"neuron type kblad 10","x":[300.0,276.4,252.8,229.2,205.6,182.0,158.39999999999998,134.79999999999998,111.19999999999999,87.6,64.0],"y":[125.0,157.5,190.0,222.5,255.0,287.5,320.0,352.5,385.0,417.5,450.0],"type":"scatter","uid":"91869e95-5ed7-4435-a8d3-24402ee17bd5"},{"hoverinfo":"text","line":{"color":"#FF0000"},"mode":"lines","name":"neuron type kblad 10","showlegend":false,"text":"neuron type kblad 10","x":[64.0,87.6,111.2,134.8,158.4,182.0,205.60000000000002,229.20000000000002,252.8,276.4,300.0],"y":[450.0,482.5,515.0,547.5,580.0,612.5,645.0,677.5,710.0,742.5,775.0],"type":"scatter","uid":"0644ad62-f4a3-45c5-a2db-15bc76b9435f"},{"hoverinfo":"text","marker":{"symbol":"circle"},"mode":"markers","name":"first sacral dorsal root ganglion","text":"first sacral dorsal root ganglion","x":[214],"y":[450.0],"type":"scatter","uid":"a11cf7a5-d08e-4286-a976-e4c7290184e4"},{"hoverinfo":"text","line":{"color":"#FF0000"},"mode":"lines","name":"neuron type kblad 10","showlegend":false,"text":"neuron type kblad 10","x":[300.0,291.4,282.8,274.2,265.6,257.0,248.39999999999998,239.8,231.2,222.6,214.0],"y":[125.0,157.5,190.0,222.5,255.0,287.5,320.0,352.5,385.0,417.5,450.0],"type":"scatter","uid":"50cb0f6a-a412-49f2-9267-24cf6dbdf86d"},{"hoverinfo":"text","line":{"color":"#FF0000"},"mode":"lines","name":"neuron type kblad 10","showlegend":false,"text":"neuron type kblad 10","x":[214.0,222.6,231.2,239.8,248.4,257.0,265.6,274.2,282.8,291.4,300.0],"y":[450.0,482.5,515.0,547.5,580.0,612.5,645.0,677.5,710.0,742.5,775.0],"type":"scatter","uid":"7377ab82-59f9-4899-87bf-09daee66889c"},{"hoverinfo":"text","marker":{"symbol":"circle"},"mode":"markers","name":"first sacral dorsal root ganglion","text":"first sacral dorsal root ganglion","x":[364],"y":[450.0],"type":"scatter","uid":"663c4d45-d6c0-47b4-83bb-afc74928733f"},{"hoverinfo":"text","line":{"color":"#FF0000"},"mode":"lines","name":"neuron type kblad 10","showlegend":false,"text":"neuron type kblad 10","x":[300.0,306.4,312.8,319.2,325.6,332.0,338.4,344.8,351.2,357.6,364.0],"y":[125.0,157.5,190.0,222.5,255.0,287.5,320.0,352.5,385.0,417.5,450.0],"type":"scatter","uid":"3297a93b-c5f7-4c4c-a7c3-b4e96c66bfbf"},{"hoverinfo":"text","line":{"color":"#FF0000"},"mode":"lines","name":"neuron type kblad 10","showlegend":false,"text":"neuron type kblad 10","x":[364.0,357.6,351.2,344.8,338.4,332.0,325.6,319.2,312.8,306.4,300.0],"y":[450.0,482.5,515.0,547.5,580.0,612.5,645.0,677.5,710.0,742.5,775.0],"type":"scatter","uid":"672055be-23a5-4870-a702-988947ee9eaa"},{"hoverinfo":"text","marker":{"symbol":"circle"},"mode":"markers","name":"first sacral dorsal root ganglion","text":"first sac ...
