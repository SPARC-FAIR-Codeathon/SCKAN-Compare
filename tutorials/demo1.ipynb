# %% [raw]
# # install relevant packages
# !pip install --quiet sckan-compare==0.1.0

# %%
#import the base class to access all features
from sckan_compare import SckanCompare

# access query sub-module; we can add all template queries in here and import as required
from sckan_compare import query

# %%
# species="Mus musculus"
species = "Rattus norvegicus"
# species="Homo sapiens"

# creating an instance of our class
sc = SckanCompare()

# to execute a SPARQL query
result = sc.execute_query(query.neuron_path_query, species=species)
result_df = sc.get_filtered_dataframe(result, species=species)

# just to show output obtained
print(result_df.shape)
# Out:
# (749, 10)

# %% [markdown]
# ## Ploting neuronal connectivity on basic anatomy map

# %%
fig = sc.plot_dataframe_anatomy_vis(result_df, species=species)
fig
# Out:
# FigureWidget({
#     'data': [{'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '9578229b-19cb-46d0-a609-c43306d20830',
#               'x': [24, 25, 25, 24, 24],
#               'y': [2, 2, 3, 3, 2]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '1226cc67-a15c-4867-ac00-afd1b7c71928',
#               'x': [26, 27, 27, 26, 26],
#               'y': [2, 2, 3, 3, 2]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '2c342771-3916-4ed0-85bc-5eac38129fea',
#               'x': [1, 5, 5, 1, 1],
#               'y': [3, 3, 7, 7, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'aa015684-78a0-4ace-bb2f-a388caf30540',
#               'x': [5, 6, 6, 5, 5],
#               'y': [3, 3, 7, 7, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '53381bfc-6c96-42f2-94c2-ffcee4acca14',
#               'x': [6, 8, 8, 6, 6],
#               'y': [5, 5, 6, 6, 5]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '53e4a4cf-897d-4733-b67c-02bab9954442',
#               'x': [7, 9, 9, 7, 7],
#               'y': [4, 4, 5, 5, 4]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '4f850614-3104-433b-8770-bce9a2a0aab6',
#               'x': [8, 10, 10, 8, 8],
#               'y': [5, 5, 6, 6, 5]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '180b5638-c3a9-4a1a-a110-c7466e79813a',
#               'x': [10, 18, 18, 10, 10],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '1d03d2b8-3535-45b6-b91a-f9bb2d375994',
#               'x': [18, 31, 31, 18, 18],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '1b4139e6-5497-4d9c-892b-05526febf708',
#               'x': [31, 37, 37, 31, 31],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '7acafbdb-9495-40c5-bf33-5265322c8871',
#               'x': [37, 41, 41, 37, 37],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'c9f59ffb-f3c3-4d25-81a8-c1d617873b7f',
#               'x': [41, 42, 42, 41, 41],
#               'y': [3, 3, 5, 5, 3]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'a226c02c-3959-43be-9509-18f4c509407d',
#               'x': [10, 41, 41, 10, 10],
#               'y': [5, 5, 6, 6, 5]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '269ffbb6-8f8e-4a29-9a25-292351693218',
#               'x': [10, 11, 11, 10, 10],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '2481d874-c515-4039-9476-b4cffdd6f5f4',
#               'x': [13, 14, 14, 13, 13],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'a8c0cf64-460a-441b-894d-21292826ff4f',
#               'x': [17, 18, 18, 17, 17],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '6bf89009-f7fa-4c9a-87db-0805c5c953d8',
#               'x': [18, 41, 41, 18, 18],
#               'y': [6, 6, 7, 7, 6]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'e7e7424c-4231-4e71-98bd-2bd51fddbbb4',
#               'x': [10, 13, 13, 10, 10],
#               'y': [7, 7, 8, 8, 7]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '2bf3a455-28ec-4e3a-9614-38e4178a52c2',
#               'x': [35, 38, 38, 35, 35],
#               'y': [7, 7, 8, 8, 7]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '2fcd57a7-f702-43ec-8c2f-8cf292ecf59f',
#               'x': [6, 8, 8, 6, 6],
#               'y': [8, 8, 9, 9, 8]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '9e14c0a7-cfd5-4d0c-8727-5a0a59edf7d5',
#               'x': [15, 17, 17, 15, 15],
#               'y': [8, 8, 9, 9, 8]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'cc030290-8535-4485-8f51-8693ba4698e4',
#               'x': [19, 20, 20, 19, 19],
#               'y': [8, 8, 9, 9, 8]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '787b7b88-fb11-4368-8655-e259a4bb6dcc',
#               'x': [6, 8, 8, 7, 7, 6, 6],
#               'y': [9, 9, 11, 11, 10, 10, 9]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '9ac26b18-a783-4abe-a78f-4f96459ec8c2',
#               'x': [18, 21, 21, 18, 18],
#               'y': [9, 9, 11, 11, 9]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'f9028627-675a-4234-ae0b-e708bc69d0f2',
#               'x': [21, 23, 23, 21, 21],
#               'y': [9, 9, 10, 10, 9]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '485a1cae-0f4f-47d4-840a-834fd32d55a8',
#               'x': [29, 30, 30, 29, 29],
#               'y': [13, 13, 14, 14, 13]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '199d421e-0692-4373-954f-fbae40150573',
#               'x': [40, 41, 41, 40, 40],
#               'y': [10, 10, 11, 11, 10]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '9e31bc0a-1569-4246-8610-8d8f10916e25',
#               'x': [18, 28, 28, 18, 18],
#               'y': [11, 11, 13, 13, 11]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'f63f3ad7-96d0-4fb7-a064-7610c6e5d9d8',
#               'x': [29, 41, 41, 29, 29],
#               'y': [11, 11, 13, 13, 11]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '39778ba1-098d-4a49-adff-32da663ccf2f',
#               'x': [22, 23, 23, 22, 22],
#               'y': [13, 13, 14, 14, 13]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '2d256759-2a70-4b73-9b23-4aa6bd6edf99',
#               'x': [24, 25, 25, 24, 24],
#               'y': [13, 13, 14, 14, 13]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '2cb655f2-76c9-4267-8a62-acd64d48c361',
#               'x': [18, 41, 41, 18, 18],
#               'y': [14, 14, 16, 16, 14]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '9231d8f7-69ef-4b2c-949d-20068817a970',
#               'x': [37, 38, 38, 37, 37],
#               'y': [16, 16, 17, 17, 16]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': '6f911a60-be3f-4eb8-83fc-1adc5cc76e97',
#               'x': [40, 41, 41, 40, 40],
#               'y': [16, 16, 17, 17, 16]},
#              {'fill': 'toself',
#               'fillcolor': '#C5CAE9',
#               'hoverinfo': 'text',
#               'hoveron': 'fills',
#               'line': {'color': '#4051BF'},
#               'mode': 'lines',
#               'showlegend': False,
#               'text': '<set name>',
#               'type': 'scatter',
#               'uid': 'ee3c3f78-ff4a-4149-8e99-792eabb6659f',
#               'x': [35, 41, 41, 35, 35],
#               'y': [17, 17, 19, 19, 17]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'f5449011-8acf-4003-a3d1-cfdb9a65cfe9',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Dome of the Bladder',
#               'text': 'Dome of the Bladder',
#               'type': 'scatter',
#               'uid': '554ccbb5-c518-483a-a905-69d4300f2d5d',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': 'da9b413c-24c8-40f7-a933-4c67f030ed7b',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 1',
#               'showlegend': False,
#               'text': 'neuron type kblad 1',
#               'type': 'scatter',
#               'uid': '9fb2a69f-46b1-40d0-995d-bc5283c066d6',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 15.9, 15.3, 14.7, 14.1, 13.5, 12.899999999999999, 12.3,
#                     11.7, 11.1, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 1',
#               'showlegend': False,
#               'text': 'neuron type kblad 1',
#               'type': 'scatter',
#               'uid': 'd046d59e-4b10-4f2a-9c1a-c3817e799e03',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'fefb00a2-4728-422a-ba56-94650e4a319e',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'neck of urinary bladder',
#               'text': 'neck of urinary bladder',
#               'type': 'scatter',
#               'uid': 'dad203b6-1436-4938-aa86-eb1a7eb7343c',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': 'd24a6866-4bfb-4bc9-b1bb-219226231661',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 1',
#               'showlegend': False,
#               'text': 'neuron type kblad 1',
#               'type': 'scatter',
#               'uid': '0add3c9e-9799-4990-9e17-9faf0bf13cbb',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 15.9, 15.3, 14.7, 14.1, 13.5, 12.899999999999999, 12.3,
#                     11.7, 11.1, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 1',
#               'showlegend': False,
#               'text': 'neuron type kblad 1',
#               'type': 'scatter',
#               'uid': '78f50477-dae5-4b38-8824-561818a265a3',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'b8d77a7f-0dc9-445b-9d4d-28feeaed4d06',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': '22f74945-89ac-4b1e-83f8-150ddc7adc82',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '90019369-90d4-46c1-a43c-43689e41769f',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'e6f1b1c0-1d3d-4a49-884e-0980427a954e',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'eb5b7944-184b-4c24-a6d9-0d8efb262ffc',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '8814b9b7-dac2-4d21-837b-7b0d783caca4',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': '8c162eaa-6fbb-4941-b074-dd1a41c55639',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'cfa06f43-9109-4bcf-8df7-907631865617',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '601e7291-ed65-409a-98f1-21dc0ffeb868',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'd13248c7-5740-47fb-99cc-cb9d51935bfc',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.1, 15.7, 15.3, 14.9, 14.5, 14.1, 13.7, 13.3, 12.9,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '1ece43b5-177b-470a-ade5-2d84e8542473',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': '71b70cdc-6db7-4a8a-a960-12e6c46e468f',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '612cdf88-53d3-43c9-ac60-45967a44fcc0',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '3039d4c2-ad6f-422a-8c73-2053fa164995',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '99b01fab-1e7e-405c-8642-06f2b908f52f',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.1, 15.7, 15.3, 14.9, 14.5, 14.1, 13.7, 13.3, 12.9,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'bcf2d242-684b-44f5-99a9-730dad8312ef',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': '6bab07db-1b36-424f-b7a6-dfe70cf08613',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'white matter of spinal cord',
#               'text': 'white matter of spinal cord',
#               'type': 'scatter',
#               'uid': 'fadf8843-6e9c-49a9-969f-09e175fd9368',
#               'x': [26.5],
#               'y': [2.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'd8996e8d-2b3f-4d6c-a44a-56f6977e4f2a',
#               'x': [37.5, 36.4, 35.3, 34.2, 33.1, 32.0, 30.9, 29.799999999999997,
#                     28.7, 27.6, 26.5],
#               'y': [5.5, 5.2, 4.9, 4.6, 4.3, 4.0, 3.6999999999999997, 3.4,
#                     3.0999999999999996, 2.8, 2.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'f7c851e8-9068-47ec-989a-6d2b5fe7cc17',
#               'x': [26.5, 27.9, 29.3, 30.700000000000003, 32.1, 33.5,
#                     34.900000000000006, 36.3, 37.7, 39.1, 40.5],
#               'y': [2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '02ce5ffe-1e2c-4e55-a63d-65dd50b1513e',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder neck',
#               'text': 'Arteriole in connective tissue of bladder neck',
#               'type': 'scatter',
#               'uid': '53c6486d-82fe-46d5-b980-3d07722f947a',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '98565ff2-2004-4b7a-aa89-28d2178edc4f',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c730420d-b49a-4d8b-826f-78ddc6a991fd',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'fc39f035-2517-426c-b072-00afc460fd1c',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'e401be74-abd9-4f33-9517-586ea679c1ca',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder neck',
#               'text': 'Arteriole in connective tissue of bladder neck',
#               'type': 'scatter',
#               'uid': '339fe18a-b911-455d-b37a-299f47bfa18d',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'a4ee737e-8879-46a8-ba54-2d28c510db35',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '100d42a4-4530-4739-b012-41d18b9120c9',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '5240408d-794f-4b1b-b768-ca5ea281a90b',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.1, 15.7, 15.3, 14.9, 14.5, 14.1, 13.7, 13.3, 12.9,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'bc77d1ea-8a9b-4f98-9d67-7a35e50e2de5',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder neck',
#               'text': 'Arteriole in connective tissue of bladder neck',
#               'type': 'scatter',
#               'uid': 'a845d875-dd6f-4a6c-9df9-46b383456e0b',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '6dfecf1c-7a22-431f-872c-61297e93e5e8',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '660164cb-806c-4fdc-b7e5-fe0ad43cc1e3',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'ed1c1074-f96c-4e3d-87c7-cdc600f2a090',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.1, 15.7, 15.3, 14.9, 14.5, 14.1, 13.7, 13.3, 12.9,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'f986347d-d720-487d-b051-3efa1abd65f3',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder neck',
#               'text': 'Arteriole in connective tissue of bladder neck',
#               'type': 'scatter',
#               'uid': '4fbc341d-e7c4-41aa-9e80-da42d71a6d0a',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'white matter of spinal cord',
#               'text': 'white matter of spinal cord',
#               'type': 'scatter',
#               'uid': 'd47c7780-c05a-445c-9bea-224a97ee4a55',
#               'x': [26.5],
#               'y': [2.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '328df2a7-8bb1-4b23-b54c-45c0a0fba977',
#               'x': [37.5, 36.4, 35.3, 34.2, 33.1, 32.0, 30.9, 29.799999999999997,
#                     28.7, 27.6, 26.5],
#               'y': [5.5, 5.2, 4.9, 4.6, 4.3, 4.0, 3.6999999999999997, 3.4,
#                     3.0999999999999996, 2.8, 2.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '8645e146-06c0-4e45-ab38-066e1191de20',
#               'x': [26.5, 27.9, 29.3, 30.700000000000003, 32.1, 33.5,
#                     34.900000000000006, 36.3, 37.7, 39.1, 40.5],
#               'y': [2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5, 10.5, 11.5, 12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': 'a6107b32-0de3-4f89-a0d9-145b17da1463',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Dome of the Bladder',
#               'text': 'Dome of the Bladder',
#               'type': 'scatter',
#               'uid': 'ecf309cf-6c56-4e27-9d24-e86262a91e6d',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': 'cce03e5c-d548-4bcf-bc92-bf78af90850d',
#               'x': [40.5],
#               'y': [10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c2ff3d80-ad07-48cc-9a96-ee9fe4ceff32',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 8.5, 9.0, 9.5, 10.0, 10.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '95bac268-a581-4ca0-bce1-0d43d38f7e20',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [10.5, 10.7, 10.9, 11.1, 11.3, 11.5, 11.7, 11.9, 12.1, 12.3,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '8d9c34f8-f3ea-40de-b727-135e6bfd3076',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Dome of the Bladder',
#               'text': 'Dome of the Bladder',
#               'type': 'scatter',
#               'uid': '00e8af80-65e8-45b8-bfe9-c20dc7d04a6b',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'b8d062b3-b3a8-4db0-a90f-bf3d9a696006',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'e28feb91-2108-44a4-ba09-1f08b1034ffe',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'f7dc04f5-4f41-4818-9fac-dc91040bdefc',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.1, 15.7, 15.3, 14.9, 14.5, 14.1, 13.7, 13.3, 12.9,
#                     12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '8145c2cf-274d-48ee-bb1a-72f179925d66',
#               'x': [37.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Dome of the Bladder',
#               'text': 'Dome of the Bladder',
#               'type': 'scatter',
#               'uid': '23664609-dc33-4616-b285-60d2a65b2268',
#               'x': [40.5],
#               'y': [12.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '4e24fc23-0aec-470a-8275-00c6644ac0a1',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '8644273e-7826-49f1-bb05-8168093c4c37',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '6e907a9a-3b7e-4bb0-93a1-b26f988b8e09',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.1, 15.7, 15.3, 14.9, 14.5, 14.1, 13.7, 13.3, 12.9,
# ...
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'major pelvic ganglion',
#               'text': 'major pelvic ganglion',
#               'type': 'scatter',
#               'uid': '373d5cfb-6dd6-4021-ac98-73ead2b5dbfc',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '3ab628f5-d700-49b7-a33f-c63f1343bf91',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'showlegend': False,
#               'text': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '5a70d260-3c53-4eaa-9cec-d81f2c863be5',
#               'x': [37.5, 37.8, 38.1, 38.4, 38.7, 39.0, 39.3, 39.6, 39.9, 40.2,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'showlegend': False,
#               'text': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '90f02c51-b304-425f-81a2-bea3f0d7d317',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5,
#                     16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Sixth lumbar spinal cord segment',
#               'text': 'Sixth lumbar spinal cord segment',
#               'type': 'scatter',
#               'uid': '971e2722-0734-4438-a9e5-fe5de12f390e',
#               'x': [36.5],
#               'y': [5.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'major pelvic ganglion',
#               'text': 'major pelvic ganglion',
#               'type': 'scatter',
#               'uid': '15547d95-59a7-40de-aa51-3ceee1379c0a',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': 'c96998f8-0a9f-4462-b670-13137ff53888',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'showlegend': False,
#               'text': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '8883264e-bb54-4252-9b09-fa72743eb910',
#               'x': [36.5, 36.9, 37.3, 37.7, 38.1, 38.5, 38.9, 39.3, 39.7, 40.1,
#                     40.5],
#               'y': [5.5, 6.6, 7.7, 8.8, 9.9, 11.0, 12.100000000000001,
#                     13.200000000000001, 14.3, 15.4, 16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'showlegend': False,
#               'text': 'L6-S1 spinal cord to major pelvic ganglion via pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': 'fa403921-a3d7-4191-a529-00fbfd26ca41',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5,
#                     16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'major pelvic ganglion',
#               'text': 'major pelvic ganglion',
#               'type': 'scatter',
#               'uid': '41f2eccc-2af3-4844-abe8-72395a5cd224',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'seminal vesicle epithelium',
#               'text': 'seminal vesicle epithelium',
#               'type': 'scatter',
#               'uid': '44c78530-fbea-419e-b517-2c3a45eb02ae',
#               'x': [37.5],
#               'y': [17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first accessory pelvic ganglion',
#               'text': 'first accessory pelvic ganglion',
#               'type': 'scatter',
#               'uid': '7a6fcd00-de49-4d43-b82a-44ee848cf5ae',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': 'fd315d42-48f0-4950-84ea-453a3179f2ea',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5,
#                     16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': '4e0b745e-690a-4c93-9192-5c9451dd6b13',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 16.6, 16.7, 16.8, 16.9, 17.0, 17.1, 17.2, 17.3, 17.4,
#                     17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'major pelvic ganglion',
#               'text': 'major pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'b01716d1-f0d4-446e-bdcb-47131834e6ad',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'seminal vesicle epithelium',
#               'text': 'seminal vesicle epithelium',
#               'type': 'scatter',
#               'uid': '6b0b5db1-8b84-449f-bdd0-a2fb3906cdee',
#               'x': [37.5],
#               'y': [17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'postganglionic parasympathetic fiber',
#               'text': 'postganglionic parasympathetic fiber',
#               'type': 'scatter',
#               'uid': '235cd947-09da-4b77-9f6e-814e74408324',
#               'x': [35.5],
#               'y': [7.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': 'fbff4ed7-4de6-461f-aef3-ac76f1a68e74',
#               'x': [40.5, 40.0, 39.5, 39.0, 38.5, 38.0, 37.5, 37.0, 36.5, 36.0,
#                     35.5],
#               'y': [16.5, 15.6, 14.7, 13.8, 12.9, 12.0, 11.1, 10.2, 9.3, 8.4, 7.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to semin' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': 'd1f5dd56-1f0e-42cf-aa6d-dc753c7d6324',
#               'x': [35.5, 35.7, 35.9, 36.1, 36.3, 36.5, 36.7, 36.9, 37.1, 37.3,
#                     37.5],
#               'y': [7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'major pelvic ganglion',
#               'text': 'major pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'd41dd310-574a-4d51-85d9-4f66171bdad3',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'muscular coat of seminal vesicle',
#               'text': 'muscular coat of seminal vesicle',
#               'type': 'scatter',
#               'uid': '5cd5ce0a-7663-4195-86a3-d621357a88d9',
#               'x': [37.5],
#               'y': [17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first accessory pelvic ganglion',
#               'text': 'first accessory pelvic ganglion',
#               'type': 'scatter',
#               'uid': 'ce694a6d-0635-46b8-bd84-8784aef8211c',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': '4a48c7a9-47aa-4501-afad-621bcbdb2338',
#               'x': [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 40.5,
#                     40.5],
#               'y': [16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5, 16.5,
#                     16.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': '7a0de83e-94ac-4663-beba-026c68fb9758',
#               'x': [40.5, 40.2, 39.9, 39.6, 39.3, 39.0, 38.7, 38.4, 38.1, 37.8,
#                     37.5],
#               'y': [16.5, 16.6, 16.7, 16.8, 16.9, 17.0, 17.1, 17.2, 17.3, 17.4,
#                     17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'major pelvic ganglion',
#               'text': 'major pelvic ganglion',
#               'type': 'scatter',
#               'uid': '3ea02ea3-c8d5-4f30-8b1e-9de034c6aa13',
#               'x': [40.5],
#               'y': [16.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#FFFF00', 'line': {'color': '#FF0000', 'width': 2}, 'size': 10, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'muscular coat of seminal vesicle',
#               'text': 'muscular coat of seminal vesicle',
#               'type': 'scatter',
#               'uid': '285392ee-6206-46f4-afb1-42d248305255',
#               'x': [37.5],
#               'y': [17.5]},
#              {'hoverinfo': 'text',
#               'marker': {'color': '#00FF00', 'line': {'color': '#000000', 'width': 2}, 'size': 7, 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'postganglionic parasympathetic fiber',
#               'text': 'postganglionic parasympathetic fiber',
#               'type': 'scatter',
#               'uid': '67e0391a-8bcf-4344-99e2-835b3822d671',
#               'x': [35.5],
#               'y': [7.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': 'cf0aeb42-eab8-4b33-8ea3-6a1c3ef79407',
#               'x': [40.5, 40.0, 39.5, 39.0, 38.5, 38.0, 37.5, 37.0, 36.5, 36.0,
#                     35.5],
#               'y': [16.5, 15.6, 14.7, 13.8, 12.9, 12.0, 11.1, 10.2, 9.3, 8.4, 7.5]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000', 'width': 2},
#               'mode': 'lines',
#               'name': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'showlegend': False,
#               'text': ('major pelvic ganglion to muscu' ... 'nglionic parasympathetic fiber'),
#               'type': 'scatter',
#               'uid': 'fd905303-4404-43a2-a33b-aad321c988ff',
#               'x': [35.5, 35.7, 35.9, 36.1, 36.3, 36.5, 36.7, 36.9, 37.1, 37.3,
#                     37.5],
#               'y': [7.5, 8.5, 9.5, 10.5, 11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5]}],
#     'layout': {'height': 500,
#                'hoverdistance': -1,
#                'hovermode': 'closest',
#                'showlegend': False,
#                'template': '...',
#                'xaxis': {'range': [0, 43],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False},
#                'yaxis': {'range': [21, 0],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False}}
# })

# %% [markdown]
# ## Plot the neuronal connectivity as a simple map

# %%
selected_Region_A = "first sacral dorsal root ganglion"
selected_Region_B = "Arteriole in connective tissue of bladder dome"

fig = sc.plot_dataframe_block_vis(result_df, selected_Region_A, selected_Region_B)
fig
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'first sacral dorsal root ganglion',
#               'text': 'first sacral dorsal root ganglion',
#               'type': 'scatter',
#               'uid': '72f2623a-4ec7-400d-a828-a3963ce76b2e',
#               'x': [300.0],
#               'y': [125]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Arteriole in connective tissue of bladder dome',
#               'text': 'Arteriole in connective tissue of bladder dome',
#               'type': 'scatter',
#               'uid': '5b3ea1ac-6b0d-4fc3-96be-11cb432a2cdd',
#               'x': [300.0],
#               'y': [775]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'bladder nerve',
#               'text': 'bladder nerve',
#               'type': 'scatter',
#               'uid': '6951cdfb-d00a-41ac-ab2e-09e61c7f75bf',
#               'x': [64],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c39eec22-8949-4fb1-8a9e-2f6ce6b5013c',
#               'x': [300.0, 276.4, 252.8, 229.2, 205.6, 182.0, 158.39999999999998,
#                     134.79999999999998, 111.19999999999999, 87.6, 64.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c55dfca8-2357-4df9-92a1-5bcc59a0983e',
#               'x': [64.0, 87.6, 111.2, 134.8, 158.4, 182.0, 205.60000000000002,
#                     229.20000000000002, 252.8, 276.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic ganglion',
#               'text': 'pelvic ganglion',
#               'type': 'scatter',
#               'uid': '1a2a8a6f-3fc3-4f89-b459-8bd562bd803b',
#               'x': [214],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'fa7ae9a6-8f36-4b52-ac6e-1e0aa2e139a9',
#               'x': [300.0, 291.4, 282.8, 274.2, 265.6, 257.0, 248.39999999999998,
#                     239.8, 231.2, 222.6, 214.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'bb3d99d6-7bd9-4164-a023-e610fe54f1c6',
#               'x': [214.0, 222.6, 231.2, 239.8, 248.4, 257.0, 265.6, 274.2, 282.8,
#                     291.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'pelvic splanchnic nerve',
#               'text': 'pelvic splanchnic nerve',
#               'type': 'scatter',
#               'uid': '6ba9cf4f-865b-4985-8a55-67970b3babcd',
#               'x': [364],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'd5198f36-402d-4f1e-b5cf-8cb4a271b19f',
#               'x': [300.0, 306.4, 312.8, 319.2, 325.6, 332.0, 338.4, 344.8, 351.2,
#                     357.6, 364.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'ac26786c-74c0-4757-96ae-2fdc63904b89',
#               'x': [364.0, 357.6, 351.2, 344.8, 338.4, 332.0, 325.6, 319.2, 312.8,
#                     306.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]},
#              {'hoverinfo': 'text',
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'white matter of spinal cord',
#               'text': 'white matter of spinal cord',
#               'type': 'scatter',
#               'uid': '33653625-1100-46f7-b73c-2f47e3b827c4',
#               'x': [514],
#               'y': [450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': 'c81963c5-bc39-4b38-8ee7-7c1c115f51af',
#               'x': [300.0, 321.4, 342.8, 364.2, 385.6, 407.0, 428.4, 449.8,
#                     471.20000000000005, 492.6, 514.0],
#               'y': [125.0, 157.5, 190.0, 222.5, 255.0, 287.5, 320.0, 352.5, 385.0,
#                     417.5, 450.0]},
#              {'hoverinfo': 'text',
#               'line': {'color': '#FF0000'},
#               'mode': 'lines',
#               'name': 'neuron type kblad 10',
#               'showlegend': False,
#               'text': 'neuron type kblad 10',
#               'type': 'scatter',
#               'uid': '7bb3ff8c-1b71-46de-bf4f-b7c6adab2143',
#               'x': [514.0, 492.6, 471.2, 449.8, 428.4, 407.0, 385.6, 364.2,
#                     342.79999999999995, 321.4, 300.0],
#               'y': [450.0, 482.5, 515.0, 547.5, 580.0, 612.5, 645.0, 677.5, 710.0,
#                     742.5, 775.0]}],
#     'layout': {'annotations': [{'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 20},
#                                 'showarrow': False,
#                                 'text': 'first sacral dorsal root ganglion',
#                                 'x': 297.0,
#                                 'xref': 'x',
#                                 'y': 0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 20},
#                                 'showarrow': False,
#                                 'text': 'Arteriole in connective tissue of bladder dome',
#                                 'x': 300.0,
#                                 'xref': 'x',
#                                 'y': 900,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'bladder nerve',
#                                 'x': 64,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'pelvic ganglion',
#                                 'x': 214,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'pelvic splanchnic nerve',
#                                 'x': 364,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'},
#                                {'align': 'center',
#                                 'font': {'color': '#000000', 'family': 'Courier New, monospace', 'size': 12},
#                                 'showarrow': False,
#                                 'text': 'white matter of spinal cord',
#                                 'x': 514,
#                                 'xref': 'x',
#                                 'y': 550.0,
#                                 'yref': 'y'}],
#                'height': 500,
#                'hoverdistance': -1,
#                'hovermode': 'closest',
#                'images': [{'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... '8Bn1KJrMY+eqcAAAAASUVORK5CYII='),
#                            'x': 300.0,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 125,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'H//r1zfwYXUiQAAAAASUVORK5CYII='),
#                            'x': 297.0,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 775,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 64,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 214,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 364,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'},
#                           {'layer': 'above',
#                            'opacity': 1.0,
#                            'sizex': 128,
#                            'sizey': 128,
#                            'source': ('...' ... 'dLTEJwE6u3mwAAAABJRU5ErkJggg=='),
#                            'x': 514,
#                            'xanchor': 'center',
#                            'xref': 'x',
#                            'y': 450.0,
#                            'yanchor': 'middle',
#                            'yref': 'y'}],
#                'shapes': [{'fillcolor': 'PaleTurquoise',
#                            'line': {'color': 'PaleTurquoise'},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 200.0,
#                            'x1': 400.0,
#                            'xref': 'x',
#                            'y0': 50,
#                            'y1': 200,
#                            'yref': 'y'},
#                           {'fillcolor': 'LightGreen',
#                            'line': {'color': 'LightGreen'},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 200.0,
#                            'x1': 400.0,
#                            'xref': 'x',
#                            'y0': 700,
#                            'y1': 850,
#                            'yref': 'y'}],
#                'showlegend': False,
#                'template': '...',
#                'xaxis': {'range': [0, 600],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False},
#                'yaxis': {'range': [900, 0],
#                          'showgrid': False,
#                          'showticklabels': False,
#                          'visible': False,
#                          'zeroline': False}}
# })
